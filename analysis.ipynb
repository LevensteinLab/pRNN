# %%
import numpy as np
import pandas as pd
import torch
import random
import math

from torch import nn

from prnn.utils.data import generate_trajectories, create_dataloader
from prnn.utils.env import make_env
from prnn.utils.agent import RandomActionAgent, RandomHDAgent, RatInABoxAgent
from prnn.utils.predictiveNet import PredictiveNet

# %%
import torch, pathlib
from prnn.utils.predictiveNet import PredictiveNet   # keep class visible

savename   = "multRNN_5win_i0_o01--s8"
root       = pathlib.Path("~/Documents/McGill/Peyrache Lab/pRNN").expanduser()
file  = root / "nets" / f"{savename}.pkl"

# 1. Load on the CPU first (safe on any machine)
net = torch.load(
    file,
    map_location="cpu",
    weights_only=False          # because the file holds a full object
)

# 2. Move to Apple‑silicon GPU if it exists
device = "mps" if torch.backends.mps.is_available() else "cpu"
net = net.to(device)            # <‑‑ this is the line that failed before

print("Network device:", next(net.parameters()).device)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[9], line 9
#       6 ckpt_file  = root / "nets" / f"{savename}.pkl"
#       8 # 1. Load on the CPU first (safe on any machine)
# ----> 9 net = torch.load(
#      10     ckpt_file,
#      11     map_location="cpu",
#      12     weights_only=False          # because the file holds a full object
#      13 )
#      15 # 2. Move to Apple‑silicon GPU if it exists
#      16 device = "mps" if torch.backends.mps.is_available() else "cpu"
#
# File ~/Documents/McGill/Peyrache Lab/pRNN/.venv/lib/python3.9/site-packages/torch/serialization.py:1495, in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1493     except pickle.UnpicklingError as e:
#    1494         raise pickle.UnpicklingError(_get_wo_message(str(e))) from None
# -> 1495 return _legacy_load(
# ...

# %%
PredictiveNet.loadNet(savename='multRNN_5win_i0_o01--s8')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 PredictiveNet.loadNet(savename='multRNN_5win_i0_o01--s8')
#
# File ~/Documents/McGill/Peyrache Lab/pRNN/prnn/utils/predictiveNet.py:617, in PredictiveNet.loadNet(savename, savefolder, suppressText)
#     615 filename = savefolder+'nets/'+savename+'.pkl'
#     616 with open(filename,'rb') as f:
# --> 617     predAgent = pickle.load(f)
#     618 if not hasattr(predAgent, "env_shell"): # backward compatibility for the nets trained before Shell update
#     619     from prnn.utils.Shell import GymMinigridShell
#
# File ~/Documents/McGill/Peyrache Lab/pRNN/.venv/lib/python3.9/site-packages/torch/storage.py:533, in _load_from_bytes(b)
#     532 def _load_from_bytes(b):
# --> 533     return torch.load(io.BytesIO(b), weights_only=False)
#
# ...

# %%
# 1) Ask any parameter
print(next(net.parameters()).device)
# or
# 2) Use a small tensor forward‑pass and look at its dtype/device
dummy_in  = torch.zeros(1, 1, net.input_size)          # adjust shape if needed
out       = net(dummy_in)                              # forward
print(out.device)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 # 1) Ask any parameter
# ----> 2 print(next(net.parameters()).device)
#       3 # or
#       4 # 2) Use a small tensor forward‑pass and look at its dtype/device
#       5 dummy_in  = torch.zeros(1, 1, net.input_size)          # adjust shape if needed
#
# NameError: name 'net' is not defined

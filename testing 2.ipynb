# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import pandas as pd
import torch
import random
import math

from torch import nn

from prnn.utils.data import generate_trajectories, create_dataloader
from prnn.utils.env import make_env
from prnn.utils.agent import RandomActionAgent, RandomHDAgent, RatInABoxAgent
from prnn.utils.predictiveNet import PredictiveNet

# %%
import matplotlib.pyplot as plt

# %%
# env_key is the one you put in RatEnvironment.py
# package is the one you put in env.py

env = make_env(env_key='cheeseboard2', package='ratinabox_colors_Reward', act_enc='ContSpeedOnehotHD', FoV_params={"spatial_resolution": 0.05,
                           "angle_range": [0, 30],
                           "distance_range": [0.0, 1.2],
                           "beta": 10,
                           "walls_occlude": False
                           }) #add FoV here
agent = RatInABoxAgent('_')
# Out:
# /Users/hadrienpadilla/Documents/McGill/Peyrache Lab/pRNN/.venv/lib/python3.9/site-packages/ratinabox/utils.py:909: UserWarning: Found 1 unexpected params key(s) while initializing FieldOfViewBVCs object: 'walls_occlude'.
# If you intended to set this parameter, ignore this message. To see all default parameters for this class call FieldOfViewBVCs.get_all_default_params().
#   warnings.warn(

# %%
# to test if you collect observations correctly
# obs should be a tuple of two tensors
# act should be a tensor

obs, act, state, render = env.collectObservationSequence(agent, 50000)

# %%
total_steps = len(env.ag.history["t"])  
print("Total steps: ", total_steps)
#look at the history of the reward cell
# Out:
# Total steps:  50001

# %%
 
# fig = plt.figure(figsize=(10, 10))
# ax = plt.subplot(1,1,1)
fig, ax = plt.subplots(figsize=(10,10))
env.show_state_traj(40000, 50000, fig, ax)
# Out:
# WARNING: This figure has not been saved.
#     • To AUTOMATICALLY save all plots (recommended), set  `ratinabox.autosave_plots = True`
#     • To MANUALLY save plots, call                        `ratinabox.utils.save_figure(figure_object, save_title).
#       This warning will not be shown again
# HINT: You can stylize plots to make them look like repo/paper by calling `ratinabox.stylize_plots()`
#       This hint will not be shown again

# %%
import matplotlib.pyplot as plt

#env.ValNeur.history
import numpy as np
vals = np.array(env.ValNeur.history["firingrate"])[:,2]   # third neuron
vals.max()    # ➜ ~0.060
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 5
#       3 #env.ValNeur.history
#       4 import numpy as np
# ----> 5 vals = np.array(env.ValNeur.history["firingrate"])[:,2]   # third neuron
#       6 vals.max()    # ➜ ~0.060
#
# AttributeError: 'RiaBColorsRewardShell' object has no attribute 'ValNeur'

# %%
env.active_reward_idx
# Out:
# 0

# %%
prednet = PredictiveNet(env, pRNNtype='multRNN_5win_i01_o01')

# %%
# to test if pRNN works correctly with these observations

obs_pred, _, _ = prednet.predict(obs, act)

# %%
env.vision[1].sigma_distances

print(env.vision[1].sigma_distances.shape)
test_distances = np.full((60,), 0.5)
env.vision[1].sigma_distances
test_distances
# Out:
# (60,)
# array([0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5,
#        0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5, 0.5])

# %%
env.vision[1].sigma_angles
test_angles = np.full((60,), 5.)

# %%
print("obs shape: ", obs[0].shape)
prednet.plotObservationSequence(obs, render, obs_pred, state, timesteps=range(4,10))
# Out:
# obs shape:  torch.Size([1, 100001, 180])
# (921600,)
# (921600,)
# (921600,)
# (921600,)
# (921600,)
# (921600,)
# (921600,)
# (921600,)
# (921600,)
# (921600,)
# (921600,)
# (921600,)

# %%
# when you're sure that everything's set, you may want to generate some data with this
# it will save a bunch of trajectories in the folder you specify, and then you can train pRNNs faster
# withput having to collect data every time

#generate_trajectories(env, agent, n_trajs=10240, seq_length=1000, folder='Data')
generate_trajectories(env, agent, n_trajs=100, seq_length=1000, folder='Data')
# Out:
# Found existing data, will generate more data if needed

# %%
create_dataloader(env, agent, 100, 1000,
                          'Data', batch_size=4, num_workers=1)
# Out:
# Found existing data, will generate more data if needed

# %%
# when you have data generated, you can test if everything goes smoothly with this

prednet.useDataLoader = True
prednet.trainingEpoch(env, agent,
                            sequence_duration=500,
                            num_trials=10,
                            batch_size=2)
# Out:
# Training pRNN on cpu...
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[17], line 4
#       1 # when you have data generated, you can test if everything goes smoothly with this
#       3 prednet.useDataLoader = True
# ----> 4 prednet.trainingEpoch(env, agent,
#       5                             sequence_duration=500,
#       6                             num_trials=10,
#       7                             batch_size=2)
#
# File ~/Documents/McGill/Peyrache Lab/pRNN/prnn/utils/predictiveNet.py:433, in PredictiveNet.trainingEpoch(self, env, agent, sequence_duration, num_trials, with_homeostat, learningRate, forceDevice, batch_size)
#     431 except(AttributeError):
#     432     obs, act = [o.to(device) for o in obs], act.to(device)
# --> 433 steploss, sparsity, meanrate = self.trainStep(obs,act,
#     434                                               with_homeostat,
#     435                                               learningRate=learningRate,
#     436                                               batched=self.useDataLoader)
#     437 #self.addTrainingData('sequence_duration',sequence_duration)
#     438 #self.addTrainingData('clocktime',time.time()-tic)
#     439 #Until batch is implemented....
#     440 # if (bb*batch_size+c) >= 100 or bb==num_trials//batch_size-1:
#     441 if (100*bb /num_trials) % 10 == 0 or bb==num_trials-1:
#     442     # c-=100
#
# File ~/Documents/McGill/Peyrache Lab/pRNN/prnn/utils/predictiveNet.py:276, in PredictiveNet.trainStep(self, obs, act, with_homeostat, learningRate, mask, batched)
#     266 def trainStep(self, obs, act,
#     267               with_homeostat = False,
#     268               learningRate=None,
#     269               mask=None,
#     270               batched=False):
#     271     """
#     272     One training step from an observation and action sequence
#     273     (collected via obs, act = agent.getObservations(env,tsteps))
#     274     """
# --> 276     obs_pred, obs_next, h = self.predict(obs, act, mask=mask, batched=batched)
#     277     if type(obs_pred) == tuple:
#     278         obs_pred = obs_pred[0]
#
# File ~/Documents/McGill/Peyrache Lab/pRNN/prnn/utils/predictiveNet.py:232, in PredictiveNet.predict(self, obs, act, state, mask, randInit, batched, fullRNNstate)
#     229     state = self.pRNN.generate_noise(self.trainNoiseMeanStd, shape)
#     230     state = self.pRNN.rnn.cell.actfun(state)
# --> 232 obs_pred, h, obs_next = self.pRNN(obs, act, noise_params=self.trainNoiseMeanStd,
#     233                                   state=state, mask=mask, batched=batched,
#     234                                   fullRNNstate=fullRNNstate)
#     236 return obs_pred, obs_next, h
#
# File ~/Documents/McGill/Peyrache Lab/pRNN/.venv/lib/python3.9/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/McGill/Peyrache Lab/pRNN/.venv/lib/python3.9/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/Documents/McGill/Peyrache Lab/pRNN/prnn/utils/Architectures.py:416, in pRNN_multimodal.forward(self, obs, act, noise_params, state, theta, single, mask, batched, fullRNNstate)
#     414 x_t, obs_target, outmask = self.restructure_inputs(obs,act,batched)
#     415 #x_t = self.droplayer(x_t) # (should it count action???) dropout with action
# --> 416 h_t,_ = self.rnn(x_t, internal=noise_t, state=state,
#     417                  theta=theta, mask=mask, batched=batched)
#     418 if not fullRNNstate:
#     419     h_t = h_t[:,:,:self.hidden_size] #For RNNcells that output more than the hidden RNN units (ugly)
#
# File ~/Documents/McGill/Peyrache Lab/pRNN/.venv/lib/python3.9/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/McGill/Peyrache Lab/pRNN/.venv/lib/python3.9/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/Documents/McGill/Peyrache Lab/pRNN/prnn/utils/thetaRNN.py:91, in thetaRNNLayer.forward(self, input, internal, state, theta, mask, batched)
#      88     state = [i.detach() for i in state]
#      90 if batched:
# ---> 91     out, state = self.cell(inputs[i][0,:].permute(1,0),
#      92                            internals[i][0,:].permute(1,0),
#      93                            state)
#      94     out = out.unsqueeze(1)
#      95     out = out.permute(*[i for i in range(1,len(out.size()))],0)
#
# File ~/Documents/McGill/Peyrache Lab/pRNN/.venv/lib/python3.9/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/McGill/Peyrache Lab/pRNN/.venv/lib/python3.9/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/Documents/McGill/Peyrache Lab/pRNN/prnn/utils/thetaRNN.py:220, in LayerNormRNNCell.forward(self, input, internal, state)
#     218 def forward(self, input: Tensor, internal: Tensor, state: Tensor) -> Tensor:
#     219     hx = state[0]
# --> 220     i_input = torch.mm(input, self.weight_ih.t())
#     221     h_input = torch.mm(hx, self.weight_hh.t())
#     222     x = self.layernorm(i_input + h_input)
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (4x160 and 196x500)

# %%
# when you will have nets already trained, this function is what you need to load them
# by default your path should be what comes after "nets/" and before ".pkl"

prednet = PredictiveNet.loadNet('PATH TO YOUR NET')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 4
#       1 # when you will have nets already trained, this function is what you need to load them
#       2 # by default your path should be what comes after "nets/" and before ".pkl"
# ----> 4 prednet = PredictiveNet.loadNet('PATH TO YOUR NET')
#
# File ~/Documents/McGill/Peyrache Lab/pRNN/prnn/utils/predictiveNet.py:611, in PredictiveNet.loadNet(savename, savefolder, suppressText)
#     608 def loadNet(savename, savefolder='', suppressText=False):
#     609     #TODO Load in init... from filename
#     610     filename = savefolder+'nets/'+savename+'.pkl'
# --> 611     with open(filename,'rb') as f:
#     612         predAgent = pickle.load(f)
#     613     if not hasattr(predAgent, "env_shell"): # backward compatibility for the nets trained before Shell update
#
# FileNotFoundError: [Errno 2] No such file or directory: 'nets/PATH TO YOUR NET.pkl'

# %%
# At some point this may be helpful to debug the whole pipeline, you'll just need to change some parameters below


# %run trainNet_prnn.py --savefolder='test/' --pRNNtype='multRNN_5win_i01_o01' \
        --sparsity=0.1 --mean_std_ratio=1 --eg_weight_decay=1e-8 --eg_lr=2e-3 \
        --env='cheeseboard' --env_package='ratinabox_colors_Reward' --agent='RatInABoxAgent' \
        --seqdur=1000 --lr=2e-3 --numepochs=6 --numtrials=1024 --hiddensize=500 --noisestd=0.05 \
        --bias_lr=0.2 --trainBias --ntimescale=2 --actenc='ContSpeedOnehotHD' --batch_size=8 --datasetSize=10240 \
        --datasetfolder='/Data' --namext='ContSpeedOnehotHD' -s=8 --saveTrainData #TODO: update data
